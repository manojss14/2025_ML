# %% [markdown]
# <a href="https://colab.research.google.com/github/manojss14/2025_ML/blob/main/rmse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Data = pd.read_csv("./onlinefraud.xls")
Data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2846575033.py in <cell line: 0>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 Data = pd.read_csv("./onlinefraud.xls")
#       5 Data.head()
#
# ...

# %%
data = Data.sample(n=500, random_state=42)
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1452353279.py in <cell line: 0>()
# ----> 1 data = Data.sample(n=500, random_state=42)
#       2 data.head()
#
# NameError: name 'Data' is not defined

# %%
len(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3264069240.py in <cell line: 0>()
# ----> 1 len(data)
#
# NameError: name 'data' is not defined

# %%
data["type"] = data["type"].map({"CASH_OUT": 1, "PAYMENT": 2, "CASH_IN": 3, "TRANSFER": 4, "DEBIT":5})
data["isFraud"] = data["isFraud"].map({0: "No Fraud", 1: "Fraud"})
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-409566741.py in <cell line: 0>()
# ----> 1 data["type"] = data["type"].map({"CASH_OUT": 1, "PAYMENT": 2, "CASH_IN": 3, "TRANSFER": 4, "DEBIT":5})
#       2 data["isFraud"] = data["isFraud"].map({0: "No Fraud", 1: "Fraud"})
#       3 data.head()
#
# NameError: name 'data' is not defined

# %%
# Splitting the data
from sklearn.model_selection import train_test_split
x = np.array(data[["type", "amount", "oldbalanceOrg", "newbalanceOrig"]])
y = np.array(data[["isFraud"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-278576072.py in <cell line: 0>()
#       1 # Splitting the data
#       2 from sklearn.model_selection import train_test_split
# ----> 3 x = np.array(data[["type", "amount", "oldbalanceOrg", "newbalanceOrig"]])
#       4 y = np.array(data[["isFraud"]])
#
# NameError: name 'data' is not defined

# %%
from sklearn.svm import SVC
Xtrain, Xtest, ytrain, ytest = train_test_split(x, y, test_size=0.30, random_state=50)

# %%
from sklearn.impute import SimpleImputer

# Create an imputer to replace NaNs with the mean (or median, or most frequent)
imputer = SimpleImputer(strategy='mean')
xtrain = imputer.fit_transform(Xtrain)
xtest = imputer.transform(Xtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-941187609.py in <cell line: 0>()
#       3 # Create an imputer to replace NaNs with the mean (or median, or most frequent)
#       4 imputer = SimpleImputer(strategy='mean')
# ----> 5 xtrain = imputer.fit_transform(Xtrain)
#       6 xtest = imputer.transform(Xtest)
#
# NameError: name 'Xtrain' is not defined

# %%
model_li =  SVC(kernel = 'linear', random_state = 0)
model_li.fit(xtrain, ytrain)
model_li.score(xtest, ytest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1343293875.py in <cell line: 0>()
# ----> 1 model_li =  SVC(kernel = 'linear', random_state = 0)
#       2 model_li.fit(xtrain, ytrain)
#       3 model_li.score(xtest, ytest)
#
# NameError: name 'SVC' is not defined

# %%
features = np.array([[4, 9000.60, 9000.60, 0.0]])
print(model_li.predict(features))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1391547349.py in <cell line: 0>()
#       1 features = np.array([[4, 9000.60, 9000.60, 0.0]])
# ----> 2 print(model_li.predict(features))
#
# NameError: name 'model_li' is not defined

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_pred = model_li.predict(xtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-586390943.py in <cell line: 0>()
# ----> 1 y_pred = model_li.predict(xtest)
#
# NameError: name 'model_li' is not defined

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
le = LabelEncoder()
ytest_num = le.fit_transform(ytest)
ypred_num = le.transform(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2042792028.py in <cell line: 0>()
#       1 le = LabelEncoder()
# ----> 2 ytest_num = le.fit_transform(ytest)
#       3 ypred_num = le.transform(y_pred)
#
# NameError: name 'ytest' is not defined

# %%
rmse = np.sqrt(mean_squared_error(ytest_num, ypred_num))
r2 = r2_score(ytest_num, ypred_num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3651156355.py in <cell line: 0>()
# ----> 1 rmse = np.sqrt(mean_squared_error(ytest_num, ypred_num))
#       2 r2 = r2_score(ytest_num, ypred_num)
#
# NameError: name 'ytest_num' is not defined

# %%
print(f"\nRMSE (numeric comparison only): {rmse:.3f}")
print(f"R² Score (numeric comparison only): {r2:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1376048642.py in <cell line: 0>()
# ----> 1 print(f"\nRMSE (numeric comparison only): {rmse:.3f}")
#       2 print(f"R² Score (numeric comparison only): {r2:.3f}")
#
# NameError: name 'rmse' is not defined
